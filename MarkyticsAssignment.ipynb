# %%
import os 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
import pandas_datareader as pdr

# %%
mark=pd.read_excel(r"S:\Markytics\Archive\List of Stocks case study (1).xlsx")

# %%
sym=mark.iloc[:,1]

# %%
sym # Symbols Contain Spaces
# Out:
# 0      ACC
# 1      ADANIPORTS
# 2      ADANIENT
# 3      ADANIPOWER
# 4      AMBUJACEM
#           ...
# 156    PVR
# 157    TATACHEM
# 158    TATAMOTORS
# 159    TATAMTRDVR
# 160    SUNTV
# Name: SYMBOL    , Length: 161, dtype: object

# %%
# Removing Spaces
l1 = []  
for i in sym:
     s = i.split()[0]
     l1.append(s)

# %%
mark['SYM'] = l1

# %%
start=pd.datetime(2021,6,2) # 90 trading days prior
# Out:
# <ipython-input-40-1d1f3be6d956>:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   start=pd.datetime(2021,6,2) # 90 trading days prior

# %%
end=pd.datetime.today()
# Out:
# <ipython-input-41-fc6a71f2f834>:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   end=pd.datetime.today()

# %%
F=[i+'.NS' for i in mark['SYM']]

# %%
F.sort()

# %%
F.remove('NIITTECH.NS')

# %%
F.remove('TATAGLOBAL.NS')

# %%
F.remove('HEXAWARE.NS')

# %%
F.remove('INFRATEL.NS')

# %%
L=pdr.get_data_yahoo(F,start,end)['Close']

# %%
L=L.T

# %%
z=[i for i in range(1, len(L)+1)]

# %%
L['Index']=z # To remove .NS indexes

# %%
FF=[]
for i in F:
    FF.append(i[:-3])

# %%
L['Stocks']=FF

# %%
L.set_index('Index',inplace=True)

# %%
FFF=L.pop('Stocks')

# %%
L.insert(0,'Stock Name',FFF)

# %%
L
# Out:
# Date   Stock Name  2021-06-02 00:00:00  2021-06-03 00:00:00  \
# Index
# 1             ACC          1997.099976          2027.349976
# 2        ADANIENT          1546.750000          1583.099976
# 3      ADANIPORTS           811.500000           825.299988
# 4      ADANIPOWER            96.400002           100.750000
# 5      AMARAJABAT           741.349976           752.799988
# ...           ...                  ...                  ...
# 153          VEDL           275.200012           277.450012
# 154        VOLTAS          1034.400024          1111.550049
# 155         WIPRO           543.000000           539.049988
# 156       YESBANK            13.450000            13.500000
# 157          ZEEL           212.800003           219.600006
#
# Date   2021-06-04 00:00:00  2021-06-07 00:00:00  2021-06-08 00:00:00  \
# Index
# 1              2009.900024          2045.949951          2042.650024
# 2              1700.949951          1624.300049          1636.449951
# ...

# %%
L.to_excel('MarkyticsSubmission.xlsx')
